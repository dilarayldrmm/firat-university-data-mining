# %%
import pandas as pd
import numpy as np

df = pd.read_csv('train.csv')

print("Başlangıçtaki Eksik Değerler:")
print(df.isnull().sum())
# Out:
# Başlangıçtaki Eksik Değerler:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sex_age_means = df.groupby('Sex')['Age'].mean()

print("Cinsiyete Göre Yaş Ortalamaları:")
print(sex_age_means)
# Out:
# Cinsiyete Göre Yaş Ortalamaları:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
print("\n--- Veri Setinin İlk 15 Satırı (Age ve Cabin) ---")

from IPython.display import display

display(df[['Age', 'Cabin']].head(15))
# Out:
# --- Veri Setinin İlk 15 Satırı (Age ve Cabin) ---
#      Age Cabin
# 0   22.0   NaN
# 1   38.0   C85
# 2   26.0   NaN
# 3   35.0  C123
# 4   35.0   NaN
# 5    NaN   NaN
# 6   54.0   E46
# 7    2.0   NaN
# 8   27.0   NaN
# 9   14.0   NaN
# 10   4.0    G6
# 11  58.0  C103
# 12  20.0   NaN
# 13  39.0   NaN
# 14  14.0   NaN
